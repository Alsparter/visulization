# %%
#matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5,6]
y = [2,4,6,8,10,12]

# %%
plt.plot(x,y);

# %%
plt.plot(y,x);

# %%
plt.scatter(x,y)

# %%
x1 = np.linspace(1,10,300)
x1[:4]
# Out:
# array([1.        , 1.03010033, 1.06020067, 1.090301  ])

# %%
y1 = np.cos(x1)
y1[:4]
# Out:
# array([0.54030231, 0.51473283, 0.48869702, 0.46221847])

# %%
plt.plot(x1,y1)

# %%
y2 = np.sin(x1)

# %%
plt.plot(x1,y2)

# %%
m = np.random.rand(50)
n = np.random.rand(50)

# %%
m,n
# Out:
# (array([8.73057197e-02, 8.39307390e-01, 6.56172498e-01, 6.44110978e-01,
#         8.17342161e-01, 1.24091353e-01, 5.12684879e-01, 8.35456778e-01,
#         9.65888190e-01, 6.21630860e-04, 5.77583522e-02, 2.23987182e-01,
#         9.16602210e-01, 8.88592590e-01, 6.70472806e-01, 4.73685430e-01,
#         8.57671743e-01, 4.50985324e-01, 6.06845101e-02, 8.88711030e-01,
#         4.38364790e-01, 6.83591446e-01, 5.21750796e-01, 3.62702544e-02,
#         3.94973139e-01, 3.46005745e-01, 7.91883620e-01, 5.70862211e-01,
#         4.77766917e-01, 9.56293638e-01, 7.77036298e-01, 4.45749413e-01,
#         4.81812694e-01, 2.99350456e-01, 4.58933839e-01, 4.80241002e-01,
#         6.15852745e-01, 5.58839013e-01, 2.02162970e-01, 9.61089784e-01,
#         2.26159207e-01, 9.99145586e-01, 7.64275767e-01, 3.38251263e-02,
#         6.18476035e-01, 3.37457769e-01, 9.70009464e-01, 8.99383917e-01,
#         9.58017956e-01, 6.41716206e-01]),
# ...

# %%
colors = np.random.rand(50)
size = 500 * np.random.rand(50)
plt.scatter(m,n, c = colors, s = size, alpha=0.6 , marker='p')

# %%
#3d

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()

fig.add_subplot(projection='')
